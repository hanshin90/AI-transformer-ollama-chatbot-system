# %% [markdown]
# #### ChatOllama 테스트 코드

# %%
from langchain_ollama import ChatOllama

## Ollama 서버 연결 정상 & 모델 로딩
llm = ChatOllama(
    model="llama3",
    temperature=0
)

## 첫 실행 시 모델 로딩 시간 걸림 ==> 이후 빨라짐
response = llm.invoke("한국어로 한 문장으로 Agent를 설명해 주세요.")
print(response.content)
# Out:
# "Agent는 특정 목표 달성을 위해 행동을 취하는 인공 지능 시스템으로, 사용자와의 인터랙션을 통해 정보를 수집하고 분석하여 최적의 결정을 내리는 기능을 갖추고 있습니다."
